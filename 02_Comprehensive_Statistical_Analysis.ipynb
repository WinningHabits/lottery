# %% [markdown]
# <a href="https://colab.research.google.com/github/WinningHabits/lottery/blob/main/02_Comprehensive_Statistical_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the preprocessed dataset
import pandas as pd

url = 'https://raw.githubusercontent.com/WinningHabits/lottery_dataset/main/lottery-toto_upto_08.23_revised_1.xlsx'
data = pd.read_excel(url)

# %%
drawn_columns = ['Draw number 1', 'Draw number 2', 'Draw number 3', 'Draw number 4', 'Draw number 5', 'Draw number 6', 'Additional Number']

plt.figure(figsize=(12, 6))

for column in drawn_columns:
    frequency = data[column].value_counts().sort_index()
    frequency.plot(kind='bar', alpha=0.5, label=column)

plt.title('Overall Frequency of Drawn Numbers')
plt.xlabel('Number')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
print("Standard Deviation:", data['Draw number 1'].std())
print("Variance:", data['Draw number 1'].var())
# Out:
# Standard Deviation: 5.885147834588782
# Variance: 34.634965034965035

# %%
print("Standard Deviation:", data['Draw number 2'].std())
print("Variance:", data['Draw number 1'].var())
# Out:
# Standard Deviation: 8.229360705569881
# Variance: 34.634965034965035

# %%
print("Standard Deviation:", data['Draw number 3'].std())
print("Variance:", data['Draw number 1'].var())
# Out:
# Standard Deviation: 7.528670917292493
# Variance: 34.634965034965035

# %%
print("Standard Deviation:", data['Draw number 4'].std())
print("Variance:", data['Draw number 1'].var())
# Out:
# Standard Deviation: 7.603596866923266
# Variance: 34.634965034965035

# %%
print("Standard Deviation:", data['Draw number 5'].std())
print("Variance:", data['Draw number 1'].var())
# Out:
# Standard Deviation: 6.771271413118554
# Variance: 34.634965034965035

# %%
print("Standard Deviation:", data['Draw number 6'].std())
print("Variance:", data['Draw number 1'].var())
# Out:
# Standard Deviation: 5.585612553611967
# Variance: 34.634965034965035

# %%
print("Standard Deviation:", data['Additional Number'].std())
print("Variance:", data['Additional Number'].var())
# Out:
# Standard Deviation: 14.698334111082985
# Variance: 216.04102564102564

# %%
print("Mean:", data['Draw number 1'].mean())
print("Median:", data['Draw number 1'].median())
print("Mode:", data['Draw number 1'].mode())
# Out:
# Mean: 7.363636363636363
# Median: 5.0
# Mode: 0    1
# Name: Draw number 1, dtype: int64

# %%
print("Mean:", data['Draw number 2'].mean())
print("Median:", data['Draw number 2'].median())
print("Mode:", data['Draw number 2'].mode())
# Out:
# Mean: 15.409090909090908
# Median: 14.5
# Mode: 0    10
# 1    15
# 2    21
# 3    22
# Name: Draw number 2, dtype: int64

# %%
print("Mean:", data['Draw number 3'].mean())
print("Median:", data['Draw number 3'].median())
print("Mode:", data['Draw number 3'].mode())
# Out:
# Mean: 23.893939393939394
# Median: 26.0
# Mode: 0    30
# Name: Draw number 3, dtype: int64

# %%
print("Mean:", data['Draw number 4'].mean())
print("Median:", data['Draw number 4'].median())
print("Mode:", data['Draw number 4'].mode())
# Out:
# Mean: 30.40909090909091
# Median: 31.0
# Mode: 0    32
# Name: Draw number 4, dtype: int64

# %%
print("Mean:", data['Draw number 5'].mean())
print("Median:", data['Draw number 5'].median())
print("Mode:", data['Draw number 5'].mode())
# Out:
# Mean: 36.89393939393939
# Median: 37.0
# Mode: 0    37
# Name: Draw number 5, dtype: int64

# %%
print("Mean:", data['Draw number 6'].mean())
print("Median:", data['Draw number 6'].median())
print("Mode:", data['Draw number 6'].mode())
# Out:
# Mean: 43.303030303030305
# Median: 45.0
# Mode: 0    49
# Name: Draw number 6, dtype: int64

# %%
print("Mean:", data['Additional Number'].mean())
print("Median:", data['Additional Number'].median())
print("Mode:", data['Additional Number'].mode())
# Out:
# Mean: 22.666666666666668
# Median: 20.0
# Mode: 0    20
# Name: Additional Number, dtype: int64

# %%
data['Draw number 1'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: >

# %%
data.tail(10)['Draw number 1'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: >

# %%
data['Date by Month'] = pd.to_datetime(data['Date by Month'])

# %%
data['Day'] = data['Date by Month'].dt.day_name()

# %%
mondays_data = data[data['Day'] == 'Monday']
mondays_data['Draw number 1'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: >

# %%
data.groupby(['Draw number 1', 'Draw number 2']).size().sort_values(ascending=False)
# Out:
# Draw number 1  Draw number 2
# 1              3                3
#                4                2
# 5              15               2
# 15             22               2
# 8              10               2
# 4              9                2
# 12             22               1
# 6              26               1
# 7              8                1
#                13               1
#                15               1
#                33               1
# 9              11               1
# 10             20               1
# 11             14               1
#                21               1
# 12             26               1
# 6              15               1
# 13             16               1
#                23               1
#                27               1
# 14             21               1
#                30               1
# 15             29               1
# 16             21               1
# 18             20               1
# ...
